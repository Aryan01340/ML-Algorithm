# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
lab_enc=LabelEncoder()

# %%
df1=lab_enc.fit_transform(df['sex'])
df['sex']=df1
df1=lab_enc.fit_transform(df['time'])
df['time']=df1
df1=lab_enc.fit_transform(df['day'])
df['day']=df1
df1=lab_enc.fit_transform(df['smoker'])
df['smoker']=df1

# %%
x = df.drop('total_bill',axis = 1)

# %%
y = df[['total_bill']]

# %%
scaler = StandardScaler()

# %%
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[-1.43994695e+00, -1.34335316e+00, -7.84789169e-01,
#          2.79157595e-01, -6.21581561e-01, -6.00192629e-01],
#        [-9.69205340e-01,  7.44405889e-01, -7.84789169e-01,
#          2.79157595e-01, -6.21581561e-01,  4.53382921e-01],
#        [ 3.63355539e-01,  7.44405889e-01, -7.84789169e-01,
#          2.79157595e-01, -6.21581561e-01,  4.53382921e-01],
#        ...,
#        [-7.22971264e-01,  7.44405889e-01,  1.27422758e+00,
#         -8.02024201e-01, -6.21581561e-01, -6.00192629e-01],
#        [-9.04025732e-01,  7.44405889e-01, -7.84789169e-01,
#         -8.02024201e-01, -6.21581561e-01, -6.00192629e-01],
#        [ 1.24660453e-03, -1.34335316e+00, -7.84789169e-01,
#          1.36033939e+00, -6.21581561e-01, -6.00192629e-01]])

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.3 , random_state = 42)

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
d_tree=DecisionTreeRegressor()

# %%
d_tree.fit(x_scaled,y)
# Out:
# DecisionTreeRegressor()

# %%
x_dtree=d_tree.predict(x_test)
x_dtree
# Out:
# array([19.82      , 11.90333333, 20.27      , 25.89      , 13.        ,
#        16.185     , 28.44      , 12.48      , 14.78      , 15.38      ,
#        18.165     , 10.77      , 10.05666667, 16.185     , 10.07      ,
#        18.64      , 18.71      , 21.58      , 16.45      , 41.19      ,
#        20.69      , 20.65      , 14.31      ,  9.55      , 19.525     ,
#        11.69      , 10.27      , 25.28      , 20.27      , 48.17      ,
#        38.07      ,  7.74      , 17.81      , 20.29      , 16.97      ,
#        24.08      , 12.03      , 43.11      , 13.16      , 18.24      ,
#        10.29      , 12.528     , 23.95      , 10.33      , 13.28333333,
#         3.07      , 10.59      , 18.69      ,  7.56      , 13.28      ,
#        24.27      , 27.28      , 31.71      , 15.98      , 19.49      ,
#        12.16333333,  7.25      , 17.82      , 17.26      , 15.69      ,
#        29.85      , 17.31      , 23.33      , 16.27      , 20.23      ,
#        20.92      , 15.01      ,  7.25      , 26.59      , 24.52      ,
#        20.27      , 28.15      , 17.29      , 17.355     ])

# %%
y_dtree=d_tree.predict(x_train)
y_dtree
# Out:
# array([15.53      , 20.45      , 34.65      , 25.29      , 38.37      ,
#        29.8       ,  9.78      , 25.71      , 20.08      , 10.05666667,
#        38.37      , 16.21      , 18.35      , 15.42      , 24.06      ,
#        21.7       , 13.94      , 29.03      ,  8.52      , 16.32      ,
#        17.51      , 10.29      , 40.17      , 17.47      , 16.58      ,
#        17.92      , 17.46      , 18.24      , 15.98      , 21.96      ,
#        16.43      , 13.03      , 10.29      , 13.27      , 23.17      ,
#        15.48      , 16.99      , 21.01      , 27.2       , 22.23      ,
#        11.35      , 12.528     , 11.87      , 32.9       , 24.99      ,
#        34.83      , 50.81      , 13.09      , 24.99      , 16.31      ,
#        27.05      , 18.24      , 15.77      , 12.43      , 13.39      ,
#        12.528     , 35.26      , 35.83      , 13.03      , 13.09      ,
#        24.59      , 14.26      , 17.355     , 34.3       , 31.85      ,
#        13.28333333, 11.02      ,  8.51      , 12.528     , 12.16      ,
#        40.55      , 12.02      , 16.47      , 17.59      , 30.4       ,
#        30.14      , 16.04      , 12.16333333, 39.42      , 45.35      ,
#         9.6       , 16.66      , 31.27      , 20.53      , 32.4       ,
#        22.75      , 20.69      ,  9.68      , 10.05666667, 15.69      ,
#        23.68      , 15.36      ,  9.94      , 12.528     , 13.42      ,
#        32.83      , 10.09      , 18.165     , 11.90333333, 19.44      ,
#        17.78      , 12.74      , 26.88      , 15.81      , 14.        ,
#        22.49      , 32.68      , 11.59      ,  8.58      , 21.96      ,
#        15.04      , 18.43      , 48.27      , 12.76      , 20.27      ,
#        16.29      , 20.76      , 26.86      , 11.61      , 18.26      ,
#        13.28333333, 13.42      , 18.29      , 25.56      , 25.21      ,
#        13.09      , 24.01      , 16.82      , 48.33      , 23.1       ,
#        18.905     , 12.9       , 18.905     , 11.24      , 28.55      ,
#        24.71      , 20.29      , 26.41      , 16.4       , 21.5       ,
#        12.6       , 30.46      , 19.81      , 22.82      , 16.93      ,
#        25.        , 22.12      , 10.34      , 34.81      , 12.16333333,
#        19.08      , 11.90333333, 22.42      , 12.46      , 29.93      ,
#        18.28      , 13.        , 14.73      , 28.17      , 30.06      ,
#        13.42      , 18.78      , 17.92      , 19.525     , 17.07      ,
#        20.49      , 14.83      ,  5.75      , 34.63      , 44.3       ])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
r2_score(y_train,y_dtree)
# Out:
# 0.9813403974607355

# %%
r2_score(y_test,x_dtree)
# Out:
# 0.9827202539807958

# %%
mean_absolute_error(y_test,x_dtree)
# Out:
# 0.4046441441441441

# %%
mean_squared_error(y_test,x_dtree)
# Out:
# 1.203643695195195
